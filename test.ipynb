# %%
import pandas as pd
from sklearn.cluster import HDBSCAN
from alpha_shapes import Alpha_Shaper

# %%
ALPHA = 1

data = pd.read_csv("public/mockdata.csv")
data = data.drop_duplicates(subset=['lng', 'lat'])
hdbscan = HDBSCAN(min_cluster_size=5, cluster_selection_method='leaf')
data['cluster'] = hdbscan.fit_predict(data[['lng', 'lat']])
data['coords'] = data.apply(lambda x: (x['lng'], x['lat']), axis=1)

# group the dataframe by cluster
feature_list = []
cluster_group_df = data.groupby('cluster')
for cluster, cluster_df in cluster_group_df:
  if cluster == -1:
    continue
  coords = cluster_df['coords'].tolist()
  shaper = Alpha_Shaper(coords)
  alpha_shape = shaper.get_shape(ALPHA)
  alpha_shape = pd.DataFrame(alpha_shape.exterior.coords.xy).T.rename(columns={0: 'lng', 1: 'lat'})
  feature = {
    "type": "Feature",
    "properties": {
      "cluster": cluster
    },
    "geometry": {
      "type": "Polygon",
      "coordinates": alpha_shape.values.tolist()
    }
  }
  feature_list.append(feature)
features = {
  "type": "FeatureCollection",
  "features": feature_list
}
features
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'cluster': 0},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[-76.3609305, 45.4331407],
#      [-66.8869412, 50.0234664],
#      [-64.8659804, 46.6817873],
#      [-71.06, 42.35],
#      [-73.9565551, 40.6945036],
#      [-81.138279, 35.9015016],
#      [-84.3857442, 33.9253024],
#      [-89.65, 39.8],
#      [-76.3609305, 45.4331407]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 1},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[-14.5611573, 13.5699981],
#      [-15.694045399999998, 16.4588779],
#      [-1.5257042000000003, 13.3252954],
#      [5.2344983, 13.3539251],
#      [17.0568962, 12.3783745],
#      [12.9608246, -5.007771499999999],
#      [-1.7344155000000003, 4.9536104000000005],
#      [-6.439688799999999, 6.8883341],
#      [-14.5611573, 13.5699981]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 2},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[-69.9013281, 19.539165],
#      [-71.2205376, 18.2447388],
#      [-77.4658948, 18.0651384],
#      [-82.1523251, 22.9647344],
#      [-76.9527836, 20.957938],
#      [-75.01667, 20.36667],
#      [-69.9013281, 19.539165]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 3},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[82.502677, 41.781418],
#      [75.3178952, 42.822377],
#      [78.3804417, 45.0177112],
#      [92.2225067, 47.4214312],
#      [87.5395855, 42.5246357],
#      [82.502677, 41.781418]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 4},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[-101.670897, 21.104739],
#      [-102.9937166, 22.6611943],
#      [-100.9086492, 25.5822549],
#      [-99.185752, 23.7173024],
#      [-97.8367954, 22.2016816],
#      [-99.0073673, 19.4102526],
#      [-99.1497466, 19.3387759],
#      [-101.670897, 21.104739]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 5},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[34.2824429, 10.5534497],
#      [38.1239492, 10.1769828],
#      [38.9824579, 5.8837714],
#      [35.8770642, -1.0875428],
#      [33.9750018, -3.2409636],
#      [26.9263671, -6.032966500000001],
#      [34.2824429, 10.5534497]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 6},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[23.0367512, -27.6923006],
#      [26.4370933, -15.7524721],
#      [28.2409671, -12.5502705],
#      [29.3889082, -13.6211552],
#      [35.3411388, -23.8611302],
#      [30.9958074, -29.8355529],
#      [26.667126, -29.5917671],
#      [23.0367512, -27.6923006]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 7},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[89.2318904, 23.063993],
#      [84.8672171, 27.0449005],
#      [91.016402, 28.841329],
#      [93.953264, 29.049672],
#      [89.6439924, 23.0246287],
#      [89.2318904, 23.063993]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 8},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [

#    'geometry': {'type': 'Polygon',
#     'coordinates': [[123.2064649, 40.934156],
#      [122.5200228, 40.6238989],
#      [120.869231, 40.774461],
#      [124.139465, 43.617445],
#      [124.825117, 45.141789],
#      [131.978812, 43.800779],
#      [133.0298493, 42.7989149],
#      [129.741477, 42.4324196],
#      [126.558573, 41.942393],
#      [123.2064649, 40.934156]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 32},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[44.2668203, 40.1852285],
#      [43.080345, 42.0943874],
#      [47.2432976, 42.7003378],
#      [50.0918078, 40.3802589],
#      [45.7337091, 36.7683527],
#      [44.2668203, 40.1852285]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 33},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[4.9404055, 49.7052493],
#      [5.0840393, 51.5742615],
#      [5.9372731, 51.9913857],
#      [7.4888434, 48.4621258],
#      [6.481599, 48.6511908],
#      [4.9404055, 49.7052493]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 34},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[0.5957159000000001, 49.0871049],
#      [1.6899473, 48.9990813],
#      [2.2178783, 49.0344853],
#      [2.5479245, 49.0096906],
#      [2.7594768, 48.7393933],
#      [4.7987938, 45.7782243],
#      [4.401981, 43.804723],
#      [4.131084, 43.6793979],
#      [1.9638715, 47.9035673],
#      [0.5957159000000001, 49.0871049]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 35},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[108.708991, 34.329605],
#      [107.035769, 34.751868],
#      [108.438067, 34.705306],
#      [110.084789, 34.477861],
#      [111.490964, 33.13782],
#      [108.708991, 34.329605]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 36},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[117.164388, 39.174484],
#      [116.365867, 39.912288],
#      [116.313024, 39.986293],
#      [116.6409433, 40.0966354],
#      [116.714967, 39.964054],
#      [117.672041, 39.163627],
#      [117.2401593, 39.021046],
#      [117.170921, 39.154597],
#      [117.164388, 39.174484]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 37},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[112.074588, 22.830192],
#      [112.047639, 24.034527],
#      [114.74638, 23.788392],
#      [114.346251, 22.691253],
#      [114.148724, 22.2866176],
#      [112.074588, 22.830192]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 38},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[118.752842, 34.542308],
#      [117.323725, 34.810487],
#      [116.768358, 36.182571],
#      [116.747092, 36.557474],
#      [117.251195, 35.664323],
#      [118.752842, 34.542308]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 39},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[25.2361291, 54.7305189],
#      [23.9749999, 55.2884444],
#      [24.0131821, 57.0408915],
#      [25.6100339, 57.331693],
#      [26.4507193, 55.5945618],
#      [27.4312339, 53.7815116],
#      [25.2361291, 54.7305189]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 40},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[12.0134068, 57.6613265],
#      [12.1438774, 57.9642094],
#      [12.7017317, 59.0463022],
#      [13.4676693, 59.3846971],
#      [14.4937714, 59.3138173],
#      [14.8077914, 56.8965251],
#      [14.0604538, 56.0345586],
#      [13.0258964, 55.7222135],
#      [12.5409879, 55.6689972],
#      [12.0134068, 57.6613265]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 41},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[16.2283098, 59.6136775],
#      [17.1574569, 60.6739776],
#      [18.3601496, 59.7436995],
#      [18.3648033, 59.6535297],
#      [18.0843085, 59.3462826],
#      [18.0285502, 59.3178128],
#      [16.2283098, 59.6136775]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 42},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[116.844405, 26.830199],
#      [113.717886, 26.930956],
#      [113.854556, 27.622768],
#      [115.932899, 27.999411],
#      [116.350531, 27.398759],
#      [116.844405, 26.830199]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 43},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[117.870803, 26.053583],
#      [119.560304, 25.941708],
#      [119.790168, 25.49872],
#      [119.105528, 25.318672],
#      [118.223965, 24.922044],
#      [117.870803, 26.053583]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 44},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[38.1632353, 50.6859367],
#      [39.8734276, 47.2952721],
#      [37.9579616, 46.4144282],
#      [35.8363269, 45.4451601],
#      [34.6341859, 47.5015067],
#      [36.0391858, 49.9482828],
#      [38.1632353, 50.6859367]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 45},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[37.315783, 55.9437901],
#      [38.1016955, 56.3103675],
#      [38.8768972, 56.1244724],
#      [39.2331589, 55.6967262],
#      [37.2283674, 52.8056388],
#      [37.315783, 55.9437901]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 46},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[109.989454, 29.483676],
#      [110.674706, 30.199688],
#      [111.970514, 28.906106],
#      [109.667164, 28.90499],
#      [109.989454, 29.483676]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 47},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[113.846241, 30.826816],
#      [112.899762, 30.402167],
#      [112.8915932, 30.5211502],
#      [113.8059154, 34.0236518],
#      [115.177188, 33.644743],
#      [114.91925, 32.009995],
#      [114.980217, 30.608675],
#      [113.846241, 30.826816]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 48},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[118.45323, 31.5977],
#      [118.41697, 32.200197],
#      [119.443725, 31.759482],
#      [118.844538, 31.558471],
#      [118.372655, 31.311756],
#      [118.45323, 31.5977]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 49},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[120.980736, 31.385597],
#      [121.492796, 31.2570292],
#      [121.6793537, 31.1655344],
#      [121.341969, 30.741991],
#      [120.181069, 30.713107],
#      [119.823308, 31.340637],
#      [120.980736, 31.385597]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 50},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[18.5697311, 53.6094246],
#      [17.5316201, 53.4513],
#      [18.0936055, 54.5412717],
#      [18.3894523, 54.6711201],
#      [18.5517476, 53.8819853],
#      [18.5697311, 53.6094246]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 51},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[21.6360085, 37.2284208],
#      [21.6206833, 37.5923591],
#      [20.737591, 39.1505158],
#      [21.6682269, 38.1625093],
#      [22.7494193, 37.705473],
#      [22.1364871, 37.401244],
#      [21.7155204, 37.0510081],
#      [21.6360085, 37.2284208]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 52},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[16.5670285, 45.3686282],
#      [15.90981, 46.6975886],
#      [16.4201451, 46.4054155],
#      [20.8507302, 45.2075889],
#      [20.5613514, 44.3037425],
#      [18.2051201, 43.8227415],
#      [17.398111, 44.1440673],
#      [16.5670285, 45.3686282]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 53},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[19.4690444, 40.6230031],
#      [19.5181312, 40.888872],
#      [19.7041069, 41.4744811],
#      [20.006257, 41.6089452],
#      [20.4128027, 41.9943014],
#      [20.6794676, 40.3373262],
#      [19.8451169, 40.4407041],
#      [19.4690444, 40.6230031]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 54},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[22.249713, 40.5511823],
#      [21.4591344, 40.8024032],
#      [22.79536, 41.43999],
#      [23.200121, 41.3910706],
#      [23.5206341, 41.0184587],
#      [23.0695911, 40.7512099],
#      [22.249713, 40.5511823]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 55},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[13.751438, 50.3789576],
#      [14.3596743, 50.9603536],
#      [14.6542767, 50.5658445],
#      [14.1889828, 50.1559431],
#      [13.7575556, 49.735524],
#      [13.5453919, 50.2642858],
#      [13.751438, 50.3789576]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 56},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[18.7971435, 50.6283477],
#      [20.7734253, 50.689856],
#      [22.7546149, 50.1062428],
#      [22.0152079, 50.0360024],
#      [19.1520875, 49.9166289],
#      [18.6057328, 49.8545281],
#      [18.3174408, 49.8831056],
#      [18.5296459, 50.085781],
#      [18.7971435, 50.6283477]]}},
#   {'type': 'Feature',
#    'properties': {'cluster': 57},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[16.9717754, 49.9778407],
#      [17.4637476, 49.3168925],
#      [17.1656129, 48.9200144],
#      [16.905384, 48.7320309],
#      [16.373098, 48.235668],
#      [16.4764384, 49.3457516],
#      [16.9717754, 49.9778407]]}}]}
